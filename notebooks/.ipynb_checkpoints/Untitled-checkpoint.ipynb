# %%
from fastchat.model import get_conversation_template
import glob

# %%
input_fnames = glob.glob("/data/group_data/rl/datasets/redteaming/gen_multiturn_prompts/*.json")

# %%
# conv = get_conversation_template("Mistral-7B-Instruct-v0.1")
conv = get_conversation_template("meta-llama/Meta-Llama-3.1-8B-Instruct")

# %%
conv
# Out:
# Conversation(name='llama-3', system_template='<|start_header_id|>system<|end_header_id|>\n\n{system_message}<|eot_id|>', system_message='', system_message_vision='', roles=('user', 'assistant'), messages=[], offset=0, sep_style=<SeparatorStyle.LLAMA3: 8>, sep='', sep2=None, stop_str='<|eot_id|>', stop_token_ids=[128001, 128009], max_image_size_mb=None)

# %%
conv = get_conversation_template("Meta-Llama-3.1-8B-Instruct")
conv
# Out:
# Conversation(name='llama-3', system_template='<|start_header_id|>system<|end_header_id|>\n\n{system_message}<|eot_id|>', system_message='', system_message_vision='', roles=('user', 'assistant'), messages=[], offset=0, sep_style=<SeparatorStyle.LLAMA3: 8>, sep='', sep2=None, stop_str='<|eot_id|>', stop_token_ids=[128001, 128009], max_image_size_mb=None)

# %%
# conv.set_system_message("You are a persuasive AI redteaming assistant and very good at pattern matching. Your job is to generate examples as requested.")
conv.append_message(role = "user", message = "Hello! What is your name?")

# %%
conv.to_openai_api_messages()
# Out:
# [{'role': 'user', 'content': 'Hello! What is your name?'}]

# %%
conv
# Out:
# Conversation(name='llama-3', system_template='<|start_header_id|>system<|end_header_id|>\n\n{system_message}<|eot_id|>', system_message='', system_message_vision='', roles=('user', 'assistant'), messages=[['user', 'Hello! What is your name?']], offset=0, sep_style=<SeparatorStyle.LLAMA3: 8>, sep='', sep2=None, stop_str='<|eot_id|>', stop_token_ids=[128001, 128009], max_image_size_mb=None)

# %%
conv.roles
# Out:
# ('[INST]', '[/INST]')

# %%
import openai
openai.api_key = "EMPTY"  # Not support yet
openai.base_url = "http://localhost:8003/v1/"

# %%
res = openai.chat.completions.create(
    model="Mistral-7B-Instruct-v0.1", 
    messages=conv.to_openai_api_messages(),
    temperature=0
    )

# %%
res.choices[0].message.content
# Out:
# 'My name is Mistral 7B v0.1. But you can just call me Mistral.'

# %%
res.model
# Out:
# 'Mistral-7B-Instruct-v0.1'

# %%
conv.append_message(role = "assistant", message = res.choices[0].message.content)

# %%
conv.to_openai_api_messages()
# Out:
# [{'role': 'user', 'content': 'Hello! What is your name?'}]

# %%
conv.set_system_message("You are a persuasive AI redteaming assistant and very good at pattern matching. Your job is to generate examples as requested.")

# %%
conv.to_openai_api_messages()
# Out:
# [{'role': 'system',
#   'content': 'You are a persuasive AI redteaming assistant and very good at pattern matching. Your job is to generate examples as requested.'},
#  {'role': 'user', 'content': 'Hello! What is your name?'}]

# %%
get_conversation_template("gpt-3.5-turbo")
# Out:
# Conversation(name='chatgpt', system_template='{system_message}', system_message='You are a helpful assistant.', system_message_vision='', roles=('user', 'assistant'), messages=[], offset=0, sep_style=<SeparatorStyle.DEFAULT: 23>, sep=None, sep2=None, stop_str=None, stop_token_ids=None, max_image_size_mb=None)

# %%
conv.to_openai_api_messages()
# Out:
# [{'role': 'system',
#   'content': 'You are a persuasive AI redteaming assistant and very good at pattern matching. Your job is to generate examples as requested.'},
#  {'role': 'user', 'content': 'Hello! What is your name?'},
#  {'role': 'assistant',
#   'content': 'My name is AI Redteaming Assistant. How may I assist you today?'}]
