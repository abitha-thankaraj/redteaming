# %%
import os
from redteam.utils.data_utils import read_json, write_json

# %%
FNAME = "/data/group_data/rl/datasets/redteaming/gen_multiturn_tree_attacks/generate_data/data/turn_0/defender/harmbench_generate_data_defender_0.json"
records = read_json(FNAME)

# %%
chunk_size = len(records)//10

# %%
chunked_path = "/data/group_data/rl/datasets/redteaming/gen_multiturn_tree_attacks/generate_data/data/turn_0/defender/chunked"

# %%
chunk_suffix = FNAME.split("/")[-1]

# %%
idx = 0
# for i in range(0, len(records), chunk_size):
#     print(i, i+chunk_size+1)
#     write_json(records[i:i+chunk_size+1],
#                os.path.join(chunked_path, f"chunk_{idx}_{chunk_suffix}"))
#     idx+=1
    # write_json(records[i:i+chunk_size+1], 
              # os.path.join(chunked_path, f"chunk_{idx}_{chunk_suffix}"))
# Out:
# 0 201
# 200 401
# 400 601
# 600 801
# 800 1001
# 1000 1201
# 1200 1401
# 1400 1601
# 1600 1801
# 1800 2001
